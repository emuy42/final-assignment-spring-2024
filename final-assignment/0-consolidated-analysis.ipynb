# %%
## import library
import pandas as pd

# %%
## set display code
pd.options.display.float_format = '{:,.0f}'.format

# %%
## import raw dataset 
raw_df = pd.read_excel("college-encampment-database.xlsx", sheet_name='6.18_workbook')
raw_df
# Out:
#     Unnamed: 0                                            college  \
# 0    Anna Leah                                American University
# 1    Anna Leah                           Arizona State University
# 2          NaN  Auraria Campus Encampment (University of Color...
# 3    Anna Leah                                    Barnard College
# 4    Anna Leah                           Berklee College of Music
# ..         ...                                                ...
# 106      Sabir                                      Washington DC
# 107      Sabir                 Washington University in St. Louis
# 108      Sabir                             Wayne State University
# 109      Sabir                                Wesleyan University
# 110      Sabir                                    Yale University
#
#                                                demands demand_scope  \
# 0    disclose investments, divestment, academic boy...     standard
# ...

# %%
## duplicate raw data
df_analysis = raw_df

# %%
df_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  110 non-null    object
#  1   college                     111 non-null    object
#  2   demands                     101 non-null    object
#  3   demand_scope                101 non-null    object
#  4   start_encampment            104 non-null    datetime64[ns]
#  5   OLD-end-encampment          79 non-null     object
#  6   end_encampment              86 non-null     datetime64[ns]
#  7   encampment_ongoing          86 non-null     object
#  8   OLD-encampment-size         66 non-null     object
#  9   size_encampment             68 non-null     float64
#  10  length_encampment           89 non-null     float64
#  11  OLD-protester-actions       46 non-null     object
#  12  OLD-orgs-involved           57 non-null     object
# ...

# %%
## convert all other metrics to int
df_analysis[["endowment_size","size_encampment","length_encampment","arrested_total","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","undergrad_population"]]= df_analysis[["endowment_size","size_encampment","length_encampment","arrested_total","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","undergrad_population"]].astype("float")

# %% [markdown]
# # Demand scope - selected tables

# %%
## create DF to look at demand scope - broad
df_broad = df_analysis[["demand_scope","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]].query("demand_scope == 'broad'")
df_broad.sample(10)
# Out:
#    demand_scope start_encampment end_encampment encampment_ongoing  \
# 30        broad       2024-04-26            NaT                NaN
# 68        broad       2024-04-30     2024-05-01                 no
# 88        broad       2024-05-01     2024-05-08                 no
# 7         broad       2024-04-22     2024-04-30                 no
# 81        broad       2024-04-25     2024-05-08                 no
# 59        broad       2024-04-22     2024-05-10                 no
# 17        broad       2024-04-25     2024-04-25                 no
# 85        broad       2024-04-22     2024-05-10                yes
# 57        broad       2024-04-25     2024-05-10                yes
# 52        broad       2024-04-23            NaT                NaN
#
#     size_encampment  length_encampment counterprotesters  \
# 30              NaN                NaN               NaN
# 68              NaN                  1                no
# ...

# %%
## create a separate DF to look at schools that have a standard scope
df_standard = df_analysis[["demand_scope","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]].query("demand_scope == 'standard'")
df_standard.sample(10)
# Out:
#     demand_scope start_encampment end_encampment encampment_ongoing  \
# 83      standard       2024-04-22     2024-05-10                yes
# 39      standard       2024-05-03            NaT                NaN
# 87      standard       2024-04-26     2024-04-30                 no
# 105     standard       2024-04-26     2024-04-29                 no
# 72      standard       2024-04-26     2024-05-02                 no
# 77      standard       2024-04-29     2024-04-29                 no
# 38      standard       2024-04-28     2024-05-06                 no
# 44      standard       2024-04-29            NaT                NaN
# 92      standard       2024-04-23     2024-05-10                yes
# 64      standard       2024-04-26     2024-04-30                 no
#
#      size_encampment  length_encampment counterprotesters  \
# 83                48                 18                no
# 39                60                NaN               NaN
# ...

# %%
## create a separate DF to look at schools that have a narrow scope
df_narrow = df_analysis[["demand_scope","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]].query("demand_scope == 'narrow'")
df_narrow.sample(10)
# Out:
#    demand_scope start_encampment end_encampment encampment_ongoing  \
# 69       narrow       2024-04-29     2024-05-10                yes
# 63       narrow       2024-04-25     2024-04-30                 no
# 29       narrow       2024-04-25            NaT                NaN
# 78       narrow       2024-04-26     2024-05-10                 no
# 45       narrow       2024-04-29            NaT                NaN
# 6        narrow       2024-04-27     2024-05-10                NaN
# 48       narrow       2024-04-26            NaT                NaN
# 40       narrow       2024-04-26            NaT                NaN
# 46       narrow       2024-04-25            NaT                NaN
# 27       narrow       2024-04-25     2024-05-10                yes
#
#     size_encampment  length_encampment counterprotesters  \
# 69               70                 11               yes
# 63               30                  5                no
# ...

# %% [markdown]
# ## share of schools that had counter protesters

# %%
## share of schools that had counter protestors - TOTAL
(df_analysis.value_counts("counterprotesters", normalize = True)*100).to_frame("Had counterprotesters? - TOTAL")
# Out:
#                    Had counterprotesters? - TOTAL
# counterprotesters
# no                                             63
# yes                                            37

# %%
## find share of schools that had negotiations - broad
(df_broad.value_counts("counterprotesters", normalize = True)*100).to_frame("Had counterprotesters? - broad")
# Out:
#                    Had counterprotesters? - broad
# counterprotesters
# no                                             53
# yes                                            47

# %%
## find share of schools that had negotiations - standard
(df_standard.value_counts("counterprotesters", normalize = True)*100).to_frame("Had counterprotesters? - standard")
# Out:
#                    Had counterprotesters? - standard
# counterprotesters
# no                                                65
# yes                                               35

# %%
## find share of schools that had negotiations - narrow
(df_narrow.value_counts("counterprotesters", normalize = True)*100).to_frame("Had counterprotesters? - narrow")
# Out:
#                    Had counterprotesters? - narrow
# counterprotesters
# no                                              80
# yes                                             20

# %% [markdown]
# # negotiated

# %%
## create a separate DF to look at schools with "successful" negotiations
df_negosh_success = df_analysis[["demand_scope","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]].query("negotiated == 'success'")
df_negosh_success.sample(4)
# Out:
#    demand_scope start_encampment end_encampment encampment_ongoing  \
# 99     standard       2024-04-29     2024-05-10                 no
# 5        narrow       2024-04-24     2024-04-30                 no
# 83     standard       2024-04-22     2024-05-10                yes
# 84       narrow       2024-04-22     2024-05-02                 no
#
#     size_encampment  length_encampment counterprotesters  \
# 99               30                 11               NaN
# 5               112                  6                no
# 83               48                 18                no
# 84               36                 10                no
#
#    commencement_canceled university_response  arrested_total negotiated  \
# 99                    no                 NaN              34    success
# 5                     no           let stand               0    success
# 83                    no                 NaN               1    success
# ...

# %%
## create a separate DF to look at schools with no negotiations
df_negosh_no = df_analysis[["demands","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]].query("negotiated == 'no'")
df_negosh_no.sample(10)
# Out:
#                                                demands start_encampment  \
# 85       declare, divest, divert, honor, and guarantee       2024-04-22
# 66   -  cutting all ties to Israeli universities, i...       2024-04-29
# 63                                          Divestment       2024-04-25
# 23   divest, academic boycott, amnesty for proteste...       2024-04-25
# 105                    Disclose, divest, and \ndeclare       2024-04-26
# 76   Disclosure, student oversight, termination of ...       2024-04-25
# 92                                  divest and support       2024-04-23
# 57   divesting from and boycotting entities and com...       2024-04-25
# 96                               disclose, and divest.       2024-04-29
# 21   official statement condemning genocide, disclo...       2024-04-25
#
#     end_encampment encampment_ongoing  size_encampment  length_encampment  \
# 85      2024-05-10                yes               24                 18
# ...

# %%
## create a separate DF to look at schools with failed negotiations
df_negosh_fail = df_analysis[["demands","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]].query("negotiated == 'yes'")
df_negosh_fail.sample(10)
# Out:
#                                                demands start_encampment  \
# 31   the University to divest from companies with t...       2024-04-29
# 7    divest, academic boycott, consumer boycott, am...       2024-04-22
# 82   Boycott, divest, sanction, dropping charges ag...       2024-05-06
# 98   Divest, end repression, \nand cut ties with Be...       2024-04-29
# 45   sever ties with companies tied to Israel’s mil...       2024-04-29
# 38   divesting the college’s endowment from holding...       2024-04-28
# 100                                  Divest, condemn\n       2024-04-29
# 11   divest, terminate partnerships, academic boyco...       2024-04-25
# 13   divest, academic boycott, demilitarization (?)...       2024-04-25
# 73   Disclose, divest, demilitarize, academic boyco...       2024-05-01
#
#     end_encampment encampment_ongoing  size_encampment  length_encampment  \
# 31      2024-05-10                yes              NaN                 11
# ...

# %% [markdown]
# ## public v. private split

# %%
## public v. private split for each - TOTAL
(df_analysis.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private - TOTAL")
# Out:
#                               Public v. Private - TOTAL
# school_type
# public                                               54
# private                                              45
# private, federally chartered                          1

# %%
## find public v. private split for each - success
(df_negosh_success.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private - success")
# Out:
#              Public v. Private - success
# school_type
# public                                80
# private                               20

# %%
## find public v. private split for each - no
(df_negosh_no.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private - no")
# Out:
#                               Public v. Private - no
# school_type
# public                                            55
# private                                           41
# private, federally chartered                       3

# %%
## find public v. private split for each - yes
(df_negosh_fail.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private - failed")
# Out:
#              Public v. Private - failed
# school_type
# public                               52
# private                              48

# %% [markdown]
# ## mean, median, max and min endowment size

# %%
## mean, median, max, min endowment size - TOTAL POP
df_analysis["endowment_size"].agg(["mean", "median", "max", "min"]).to_frame("Endowment size - TOTAL")
# Out:
#         Endowment size - TOTAL
# mean                     4,628
# median                   1,469
# max                     49,495
# min                          2

# %%
## find mean, median, max, min endowment size - success
df_negosh_success["endowment_size"].agg(["mean", "median", "max", "min"]).to_frame("Endowment size - successful negotiation")
# Out:
#         Endowment size - successful negotiation
# mean                                     10,419
# median                                    3,600
# max                                      49,495
# min                                          65

# %%
## find mean, median, max, min endowment size - no
df_negosh_no["endowment_size"].agg(["mean", "median", "max", "min"]).to_frame("Endowment size - no negotiation")
# Out:
#         Endowment size - no negotiation
# mean                              4,496
# median                            1,285
# max                              36,500
# min                                 192

# %%
## find mean, median, max, min endowment size - yes
df_negosh_fail["endowment_size"].agg(["mean", "median", "max", "min"]).to_frame("Endowment size - failed negotiation")
# Out:
#         Endowment size - failed negotiation
# mean                                  3,797
# median                                1,910
# max                                  13,640
# min                                      42

# %% [markdown]
# ## mean, median, max and min undergrad population

# %%
## find mean, median, max, min arrested - TOTAL
df_analysis["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population - TOTAL")
# Out:
#         Undergrad population - TOTAL
# mean                          23,422
# median                        15,792
# max                          368,722
# min                              914

# %%
## find mean, median, max, min arrested total - success
df_negosh_success["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population - successful negotiation")
# Out:
#         Undergrad population - successful negotiation
# mean                                           25,241
# median                                         30,542
# max                                            41,444
# min                                             5,867

# %%
## find mean, median, max, min arrested total - no
df_negosh_no["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population - no negotiation")
# Out:
#         Undergrad population - no negotiation
# mean                                   20,758
# median                                 19,743
# max                                   118,988
# min                                       914

# %%
## find mean, median, max, min arrested total - yes
df_negosh_fail["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population - failed negotiation")
# Out:
#         Undergrad population - failed negotiation
# mean                                       33,815
# median                                     11,483
# max                                       368,722
# min                                         1,925

# %% [markdown]
# ## share of schools that are in states with anti-BDS laws

# %%
## find share of schools that have BDS laws - TOTAL
(df_analysis.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law? - TOTAL")
# Out:
#                 Anti BDS law? - TOTAL
# anti_bds_state
# yes                                61
# no                                 39

# %%
## find share of schools that had negotiations - success
(df_negosh_success.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law? - success")
# Out:
#                 Anti BDS law? - success
# anti_bds_state
# yes                                  60
# no                                   40

# %%
## find share of schools that had negotiations - no
(df_negosh_no.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law? - no")
# Out:
#                 Anti BDS law? - no
# anti_bds_state
# yes                             69
# no                              31

# %%
## find share of schools that had negotiations - yes
(df_negosh_fail.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law? - failed")
# Out:
#                 Anti BDS law? - failed
# anti_bds_state
# yes                                 56
# no                                  44

# %% [markdown]
# # negotiation timing

# %%
## create DF
df_negotiation = df_analysis[["demand_scope","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state", "negotiation_length"]].query("negotiated == 'yes' or (negotiated == 'success')")
df_negotiation.sample(10)
# Out:
#     demand_scope start_encampment end_encampment encampment_ongoing  \
# 5         narrow       2024-04-24     2024-04-30                 no
# 8          broad       2024-04-29     2024-05-10                 no
# 74         broad       2024-04-29     2024-05-07                 no
# 69        narrow       2024-04-29     2024-05-10                yes
# 73         broad       2024-05-01     2024-05-10                yes
# 38      standard       2024-04-28     2024-05-06                 no
# 45        narrow       2024-04-29            NaT                NaN
# 25        narrow       2024-04-26            NaT                NaN
# 53         broad       2024-04-29     2024-05-03                 no
# 100     standard       2024-04-29     2024-05-10                yes
#
#      size_encampment  length_encampment counterprotesters  \
# 5                112                  6                no
# 8                 80                 11               yes
# ...

# %%
## import datetime
import datetime

# %%
## convert negotiation date into datetime for analysis
df_negotiation["negotiation_date"] = pd.to_datetime(df_negotiation["negotiation_date"])

# %%
## find mean, median, max, and min for negotiation date
df_negotiation["negotiation_date"].agg(["mean", "median", "max", "min"]).to_frame("Key stats - negotiation date")
# Out:
#         Key stats - negotiation date
# mean   2024-04-30 16:21:49.090909184
# median 2024-05-01 00:00:00.000000000
# max    2024-05-12 00:00:00.000000000
# min    2024-03-30 00:00:00.000000000

# %%
## time to negotiation length
df_negotiation["negotiation_length"].agg(["mean", "median", "max", "min"]).to_frame("Key stats - negotiation length")
# Out:
#         Key stats - negotiation length
# mean                                 6
# median                               6
# max                                 26
# min                                  0

# %% [markdown]
# # arrests

# %%
## create a separate DF to look at schools that have called the police
df_arrests = df_analysis[["demand_scope","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]].query("university_response == 'arrests'")
df_arrests.sample(10)
# Out:
#    demand_scope start_encampment end_encampment encampment_ongoing  \
# 16        broad       2024-04-23     2024-04-25                 no
# 63       narrow       2024-04-25     2024-04-30                 no
# 82     standard       2024-05-06     2024-05-07                 no
# 96     standard       2024-04-29     2024-04-29                 no
# 77     standard       2024-04-29     2024-04-29                 no
# 18       narrow       2024-04-25     2024-05-08                 no
# 74        broad       2024-04-29     2024-05-07                 no
# 29       narrow       2024-04-25            NaT                NaN
# 17        broad       2024-04-25     2024-04-25                 no
# 91     standard       2024-04-23     2024-04-29                 no
#
#     size_encampment  length_encampment counterprotesters  \
# 16              100                  2                no
# 63               30                  5                no
# ...

# %%
## create a separate DF to look at schools that let the encampment stand
df_let_stand = df_analysis[["demands","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]].query("university_response == 'let stand'")
df_let_stand.sample(10)
# Out:
#                                               demands start_encampment  \
# 5   divest, "protect free speech on campus", pardo...       2024-04-24
# 11  divest, terminate partnerships, academic boyco...       2024-04-25
# 27                   the college call for a ceasefire       2024-04-25
# 71  End the silence\nFinancial divestment\nAcademi...       2024-04-22
# 54  DISCLOSE institutional expenditure, including ...       2024-04-29
# 6               divest, official call for ceasefire,        2024-04-27
# 12  disclose, divest, defend activism and Palestin...       2024-04-29
# 55                                         Divestment       2024-03-27
# 56  1. Disclose & Divest\n2. Academic Boycott\n3. ...       2024-04-26
# 60  - support a ceasefire\n- ethical investments\n...       2024-04-29
#
#    end_encampment encampment_ongoing  size_encampment  length_encampment  \
# 5      2024-04-30                 no              112                  6
# ...

# %%
## TOTAL: share of schools with arrested students 
(df_analysis.value_counts("university_response", normalize = True)*100).to_frame("School response")
# Out:
#                      School response
# university_response
# arrests                           56
# let stand                         20
# off campus                        12
# discipline threat                  8
# agreed                             2
# dismantled                         2

# %% [markdown]
# ## share of schools that are in states with anti-BDS laws

# %%
## find share of schools that have BDS laws - TOTAL
(df_analysis.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law?")
# Out:
#                 Anti BDS law?
# anti_bds_state
# yes                        61
# no                         39

# %%
## find share of schools that had negotiations - arrests
(df_arrests.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law? - arrests")
# Out:
#                 Anti BDS law? - arrests
# anti_bds_state
# yes                                  73
# no                                   27

# %%
## find share of schools that had negotiations - let stand
(df_let_stand.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law? - let stand")
# Out:
#                 Anti BDS law? - let stand
# anti_bds_state
# no                                     50
# yes                                    50

# %% [markdown]
# ## public v. private split

# %%
## find public v. private split for each - TOTAL
(df_analysis.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private")
# Out:
#                               Public v. Private
# school_type
# public                                       54
# private                                      45
# private, federally chartered                  1

# %%
## find public v. private split for each - arrests
(df_arrests.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private")
# Out:
#                               Public v. Private
# school_type
# public                                       61
# private                                      36
# private, federally chartered                  3

# %%
## find public v. private split for each - let stand
(df_let_stand.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private")
# Out:
#              Public v. Private
# school_type
# private                     58
# public                      42

# %% [markdown]
# ## mean, median, max and min endowment size

# %%
## find public v. private split for each - TOTAL
(df_analysis.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private")
# Out:
#                               Public v. Private
# school_type
# public                                       54
# private                                      45
# private, federally chartered                  1

# %%
## find mean, median, max, min endowment size - arrests
df_arrests["endowment_size"].agg(["mean", "median", "max", "min"]).to_frame("Endowment size - arrests")
# Out:
#         Endowment size - arrests
# mean                       5,974
# median                     2,100
# max                       49,495
# min                           42

# %%
## find mean, median, max, min endowment size - let stand
df_let_stand["endowment_size"].agg(["mean", "median", "max", "min"]).to_frame("Endowment size - let stand")
# Out:
#         Endowment size - let stand
# mean                         2,552
# median                       1,100
# max                         10,000
# min                             65

# %% [markdown]
# # mean, median, max and min tuition

# %%
## find mean, median, max, min tuition - TOTAL
df_analysis[["undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private"]].agg(["mean", "median", "max", "min"])
# Out:
#         undergrad_tuition_instate  undergrad_tuition_outstate  \
# mean                       13,070                      35,741
# median                     11,713                      35,902
# max                        36,938                      59,050
# min                         3,465                      17,324
#
#         undergrad_tuition_private
# mean                       57,080
# median                     62,838
# max                        68,678
# min                         5,742

# %%
## find mean, median, max, min tuition - arrests
df_arrests[["undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private"]].agg(["mean", "median", "max", "min"])
# Out:
#         undergrad_tuition_instate  undergrad_tuition_outstate  \
# mean                       15,749                      39,036
# median                     11,698                      39,890
# max                        36,938                      59,050
# min                         3,510                      18,680
#
#         undergrad_tuition_private
# mean                       63,283
# median                     64,092
# max                        68,678
# min                        55,392

# %%
## find mean, median, max, min tuition - let stand
df_let_stand[["undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private"]].agg(["mean", "median", "max", "min"])
# Out:
#         undergrad_tuition_instate  undergrad_tuition_outstate  \
# mean                        9,736                      33,462
# median                      9,736                      33,462
# max                        13,752                      46,326
# min                         5,721                      20,598
#
#         undergrad_tuition_private
# mean                       50,367
# median                     62,560
# max                        68,230
# min                         5,742

# %% [markdown]
# ## mean, median, max and min undergrad population

# %%
## find mean, median, max, min undergrad pop - TOTAL
df_analysis["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population")
# Out:
#         Undergrad population
# mean                  23,422
# median                15,792
# max                  368,722
# min                      914

# %%
## find mean, median, max, min undergrad pop - arrests
df_arrests["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population - arrests")
# Out:
#         Undergrad population - arrests
# mean                            20,102
# median                          10,729
# max                            114,484
# min                              3,493

# %%
## find mean, median, max, min arrested total - let stand
df_let_stand["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population - let stand")
# Out:
#         Undergrad population - let stand
# mean                              13,750
# median                            11,478
# max                               33,078
# min                                1,409
