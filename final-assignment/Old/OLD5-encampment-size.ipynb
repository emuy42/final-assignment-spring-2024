# %%
## import library
import pandas as pd

# %%
## import numpy for deciles
import numpy as np

# %%
## set display code
pd.options.display.float_format = '{:,.0f}'.format

# %%
## import raw dataset 
raw_df = pd.read_excel("college-encampment-database.xlsx", sheet_name='6.18_workbook')
raw_df
# Out:
#     Unnamed: 0                                            college  \
# 0    Anna Leah                                American University
# 1    Anna Leah                           Arizona State University
# 2    Anna Leah  Auraria Campus Encampment (University of Color...
# 3    Anna Leah                                    Barnard College
# 4    Anna Leah                           Berklee College of Music
# ..         ...                                                ...
# 108      Sabir                                      Washington DC
# 109      Sabir                 Washington University in St. Louis
# 110      Sabir                             Wayne State University
# 111      Sabir                                Wesleyan University
# 112      Sabir                                    Yale University
#
#                                                demands start_encampment  \
# 0    disclose investments, divestment, academic boy...       2024-04-25
# 1    official statement of condemnation, disclose i...       2024-04-26
# 2    divest, refusal of grants or funds from milita...       2024-04-25
# 3    divest, remove NYPD from campus, reinstate SJP...       2024-04-17
# 4    divest, disclose, academic boycott, land ackno...       2024-04-25
# ..                                                 ...              ...
# 108                                                NaN              NaT
# 109  Divest, boycott, no policing,\nstop displaceme...       2024-04-27
# 110                                                NaN              NaT
# 111        Disclose, Terminate, \nDivest, and Protect.       2024-04-28
# 112                       Disclose, divest,\nReinvest.       2024-04-20
#
#           end_encampment encampment_ongoing  \
# 0    2024-05-07 00:00:00                 no
# 1    2024-04-27 00:00:00                 no
# 2    2024-05-15 00:00:00                yes
# 3    2024-04-30 00:00:00                 no
# 4    2024-04-27 00:00:00                 no
# ..                   ...                ...
# 108                  NaN                NaN
# 109  2024-04-27 00:00:00                 no
# 110                  NaN                NaN
# 111  2024-05-15 00:00:00                yes
# 112  2024-04-22 00:00:00                 no
#
#                                  OLD-encampment-size  size_encampment  \
# 0                   300 (day 1, April 25, AU joined)              300
# 1                                  400 (approximate)              400
# 2                                                100              100
# 3                                                NaN              NaN
# 4    100 (joined Northeastern University encampment)              100
# ..                                               ...              ...
# 108                                              NaN              NaN
# 109                                              NaN               11
# 110                                              NaN              NaN
# 111                                              NaN              100
# 112                                              NaN               40
#
#      length_encampment                              OLD-protester-actions  \
# 0                   12                            graffiti, flag change,
# 1                    1                                                NaN
# 2                   20  vandalism, enter student union, illegal concer...
# 3                   13                                occupied building,
# 4                    2                       alleged antisemitic language
# ..                 ...                                                ...
# 108                  0                                                NaN
# 109                  0                                                NaN
# 110                  0                                                NaN
# 111                 17                                                NaN
# 112                  2                                                NaN
#
#      ...                                 share_full_tuition anti_bds_state  \
# 0    ...              47% first-years receive financial aid             no
# 1    ...              53% first-years receive financial aid            yes
# 2    ...  28.%, 42% of first-year students received need...            yes
# 3    ...  47% of first-year students received need-based...            yes
# 4    ...  32% of first-year students received need-based...             no
# ..   ...                                                ...            ...
# 108  ...                                                NaN            NaN
# 109  ...                                                NaN            Yes
# 110  ...                                                NaN            Yes
# 111  ...                                                NaN             No
# 112  ...                                                NaN             No
#
#            city state region                   school-colors  \
# 0    Washington    DC    NaN                  004FA2, E0263c
# 1         Tempe    AZ    NaN  8C1D40, FFC627, 000000, FFFFFF
# 2        Denver    CO    NaN                  CFB87C, 000000
# 3      New York    NY    NaN          012F6B, 9fC16D, 666666
# 4        Boston    MA    NaN                  D81118, 005587
# ..          ...   ...    ...                             ...
# 108         NaN   NaN    NaN                             NaN
# 109   St. Louis    MO    NaN                             NaN
# 110     Detroit    MI    NaN                             NaN
# 111  Middletown    CT    NaN                             NaN
# 112   New Haven    CT    NaN                             NaN
#
#                       mascot  \
# 0                      eagle
# 1       Sparky the Sun Devil
# 2                       Lynx
# 3    Millie the Dancing Bear
# 4        Mingus the Jazz Cat
# ..                       ...
# 108                      NaN
# 109                      NaN
# 110                      NaN
# 111                      NaN
# 112                      NaN
#
#                                                 quotes  \
# 0                                                  NaN
# 1    "Do not let them harass any police officers," ...
# 2    "The public campus that houses Metropolitan St...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
#
#                                                 source  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                NaN
# 109  https://www.studlife.com/news/2024/04/27/prote...
# 110  https://www.freep.com/story/news/local/michiga...
# 111  https://newrepublic.com/article/181341/wesleya...
# 112  https://yaledailynews.com/blog/2024/04/28/live...
#
#                                                  notes
# 0    Part of DC encampment, student government expr...
# 1                                                  NaN
# 2    shares campus with Community College of Denver...
# 3                         protested at Columbia campus
# 4                                                  NaN
# ..                                                 ...
# 108  https://www.udc.edu/\nI am not sure what this ...
# 109                                                NaN
# 110  There is no info on encampements at Wayne Stat...
# 111                                                NaN
# 112                                                NaN
#
# [113 rows x 40 columns]

# %%
## duplicate raw data
df_analysis = raw_df

# %%
df_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  113 non-null    object
#  1   college                     113 non-null    object
#  2   demands                     101 non-null    object
#  3   start_encampment            103 non-null    datetime64[ns]
#  4   end_encampment              78 non-null     object
#  5   encampment_ongoing          85 non-null     object
#  6   OLD-encampment-size         65 non-null     object
#  7   size_encampment             67 non-null     float64
#  8   length_encampment           92 non-null     float64
#  9   OLD-protester-actions       46 non-null     object
#  10  OLD-orgs-involved           57 non-null     object
#  11  counterprotesters           49 non-null     object
#  12  OLD-inst-response           31 non-null     object
#  13  commencement_canceled       94 non-null     object
#  14  OLD-university_response     65 non-null     object
#  15  university_response         52 non-null     object
#  16  arrested_students           61 non-null     object
#  17  arrested_total              65 non-null     float64
#  18  OLD-negotiated - notes      46 non-null     object
#  19  negotiated                  61 non-null     object
#  20  negotiation_date            29 non-null     object
#  21  school_type                 110 non-null    object
#  22  OLD-endowment               96 non-null     object
#  23  endowment_size              83 non-null     float64
#  24  undergrad_population        106 non-null    float64
#  25  OLD-average                 41 non-null     object
#  26  OLD-tuition                 105 non-null    object
#  27  undergrad_tuition_instate   43 non-null     float64
#  28  undergrad_tuition_outstate  42 non-null     float64
#  29  undergrad_tuition_private   53 non-null     float64
#  30  share_full_tuition          43 non-null     object
#  31  anti_bds_state              107 non-null    object
#  32  city                        109 non-null    object
#  33  state                       110 non-null    object
#  34  region                      0 non-null      float64
#  35  school-colors               75 non-null     object
#  36  mascot                      85 non-null     object
#  37  quotes                      13 non-null     object
#  38  source                      38 non-null     object
#  39  notes                       52 non-null     object
# dtypes: datetime64[ns](1), float64(9), object(30)
# memory usage: 35.4+ KB

# %% [markdown]
# ## convert all strings to numbers

# %%
## convert all other metrics to int
df_analysis[["endowment_size","size_encampment","length_encampment","arrested_total","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","undergrad_population"]]= df_analysis[["endowment_size","size_encampment","length_encampment","arrested_total","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","undergrad_population"]].astype("float")

# %% [markdown]
# # Step 5: Are there discernible differences among schools by encampment size?

# %% [markdown]
# ## distribution of encampment size

# %%
## create DF for encampment analysis
df_encampment_size = df_analysis[["demands","start_encampment","end_encampment","encampment_ongoing","size_encampment","length_encampment","counterprotesters","commencement_canceled","university_response","arrested_total","negotiated","negotiation_date","school_type","endowment_size","undergrad_population","undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private","anti_bds_state","state"]]

# %%
## find decile distribution of encampment size

def calculate _quartiles(df_encampment_size)["size_encampment"]
np.percentile(df_encampment_size, np.arange(0, 100, 10))

# ['decile_rank'] = pd.qcut(df_encampment_size['size_encampment'], 10, 
#                                labels = False)
# df_encampment_size1.sample(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 ## find decile distribution of encampment size
# ----> 3 np.percentile(df_encampment_size, np.arange(0, 100, 10))
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4283, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281 if not _quantile_is_valid(q):
#    4282     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283 return _quantile_unchecked(
#    4284     a, q, axis, out, overwrite_input, method, keepdims)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
#    4552                         method="linear",
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#    4558                     keepdims=keepdims,
#    4559                     axis=axis,
#    4560                     out=out,
#    4561                     overwrite_input=overwrite_input,
#    4562                     method=method)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4722, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4720     else:
#    4721         arr = a.copy()
# -> 4722 result = _quantile(arr,
#    4723                    quantiles=q,
#    4724                    axis=axis,
#    4725                    method=method,
#    4726                    out=out)
#    4727 return result
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4824, in _quantile(arr, quantiles, axis, method, out)
#    4820 previous_indexes, next_indexes = _get_indexes(arr,
#    4821                                               virtual_indexes,
#    4822                                               values_count)
#    4823 # --- Sorting
# -> 4824 arr.partition(
#    4825     np.unique(np.concatenate(([0, -1],
#    4826                               previous_indexes.ravel(),
#    4827                               next_indexes.ravel(),
#    4828                               ))),
#    4829     axis=0)
#    4830 if supports_nans:
#    4831     slices_having_nans = np.isnan(arr[-1, ...])
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
## share of schools that called the police
(df_analysis.value_counts("commencement_canceled", normalize = True)*100).to_frame("Commencement status")
# Out:
#                                                     Commencement status
# commencement_canceled
# No                                                                   53
# no                                                                   37
# moved                                                                 2
# SJP boycott                                                           1
# diminished, SJP boycott                                               1
# no (May 4)                                                            1
# no, moved                                                             1
# protesters walked out                                                 1
# some banned, degree withheld pending outcome of...                    1
# yes                                                                   1

# %% [markdown]
# ## find top states for key deciles

# %%
## find top states for each - canceled
df_canceled["state"].value_counts(ascending = False).to_frame("Total schools - commencement canceled")
# Out:
#        Total schools with arrests
# state
# NY                              6
# MA                              3
# CA                              2
# GA                              2
# FL                              2
# CT                              2
# CO                              2
# PA                              2
# AZ                              1
# NM                              1
# UT                              1
# TX                              1
# NC                              1
# LA                              1
# MN                              1
# VA                              1
# IL                              1
# DC                              1
# MO                              1

# %%
## find top states for each - commencement
df_commencement["state"].value_counts(ascending = False).to_frame("Total schools - commencement happened")
# Out:
#        Total schools that let stand
# state
# NY                                6
# MA                                3
# CA                                2
# GA                                2
# FL                                2
# CT                                2
# CO                                2
# PA                                2
# AZ                                1
# NM                                1
# UT                                1
# TX                                1
# NC                                1
# LA                                1
# MN                                1
# VA                                1
# IL                                1
# DC                                1
# MO                                1

# %% [markdown]
# ## public v. private split

# %%
## find public v. private split for each - commencement canceled
(df_canceled.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private")
# Out:
#                               Public v. Private
# school_type
# public                                       59
# private                                      38
# private, federally chartered                  3

# %%
## find public v. private split for each - commencement happened
(df_commencement.value_counts("school_type", normalize = True)*100).to_frame("Public v. Private")
# Out:
#                               Public v. Private
# school_type
# public                                       59
# private                                      38
# private, federally chartered                  3

# %% [markdown]
# ## mean, median, max and min endowment size

# %%
## find mean, median, max, min endowment size - commencement canceled
df_canceled["endowment_size"].agg(["mean", "median", "max", "min"]).to_frame("Endowment size - ccommencement canceled")
# Out:
#         Endowment size - arrests
# mean                       6,084
# median                     1,850
# max                       49,495
# min                           42

# %%
## find mean, median, max, min endowment size - commencement happened
df_commencement["endowment_size"].agg(["mean", "median", "max", "min"]).to_frame("Endowment size - commencement happened")
# Out:
#         Endowment size - let stand
# mean                         6,084
# median                       1,850
# max                         49,495
# min                             42

# %% [markdown]
# ## mean, median, max and min tuition

# %%
## find mean, median, max, min tuition - commencement canceled
df_canceled[["undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private"]].agg(["mean", "median", "max", "min"])
# Out:
#         undergrad_tuition_instate  undergrad_tuition_outstate  \
# mean                       16,079                      38,915
# median                     11,439                      36,468
# max                        36,938                      59,050
# min                         3,510                      18,680
#
#         undergrad_tuition_private
# mean                       63,283
# median                     64,092
# max                        68,678
# min                        55,392

# %%
## find mean, median, max, min tuition - commencement happened
df_commencement[["undergrad_tuition_instate","undergrad_tuition_outstate","undergrad_tuition_private"]].agg(["mean", "median", "max", "min"])
# Out:
#         undergrad_tuition_instate  undergrad_tuition_outstate  \
# mean                       16,079                      38,915
# median                     11,439                      36,468
# max                        36,938                      59,050
# min                         3,510                      18,680
#
#         undergrad_tuition_private
# mean                       63,283
# median                     64,092
# max                        68,678
# min                        55,392

# %% [markdown]
# ## mean, median, max and min encampment length

# %%
## find mean, median, max, min encampment length - commencement canceled
df_canceled["length_encampment"].agg(["mean", "median", "max", "min"]).to_frame("Encampment length - commencement canceled")
# Out:
#         Encampment length - arrests
# mean                              8
# median                            6
# max                              22
# min                               0

# %%
## find mean, median, max, min encampment length - commencement happened
df_commencement["length_encampment"].agg(["mean", "median", "max", "min"]).to_frame("Encampment length - commencement happened")
# Out:
#         Encampment length - let stand
# mean                                8
# median                              6
# max                                22
# min                                 0

# %% [markdown]
# ## mean, median, max and min encampment size

# %%
## find mean, median, max, min encampment size - commencement canceled
df_canceled["size_encampment"].agg(["mean", "median", "max", "min"]).to_frame("Encampment size - commencement canceled")
# Out:
#         Encampment size - arrests
# mean                          115
# median                         42
# max                         1,000
# min                             0

# %%
## find mean, median, max, min encampment size - commencement happened
df_commencement["size_encampment"].agg(["mean", "median", "max", "min"]).to_frame("Encampment size - commencement canceled")
# Out:
#         Encampment size - let stand
# mean                            115
# median                           42
# max                           1,000
# min                               0

# %% [markdown]
# ## mean, median, max and min arrested total

# %%
## find mean, median, max, min arrested total - commencement canceled
df_canceled["arrested_total"].agg(["mean", "median", "max", "min"]).to_frame("Total arrests - commencement canceled")
# Out:
#         Total arrests - arrests
# mean                         46
# median                       26
# max                         209
# min                           0

# %%
## find mean, median, max, min arrested total - commencement happened
df_commencement["arrested_total"].agg(["mean", "median", "max", "min"]).to_frame("Total arrests - commencement happened")
# Out:
#         Total arrests - let stand
# mean                           46
# median                         26
# max                           209
# min                             0

# %% [markdown]
# ## mean, median, max and min undergrad population

# %%
## find mean, median, max, min arrested total - commencement canceled
df_canceled["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population - commencement canceled")
# Out:
#         Undergrad population - arrests
# mean                            31,594
# median                          10,610
# max                            413,099
# min                              3,493

# %%
## find mean, median, max, min arrested total - commencement happened
df_commencement["undergrad_population"].agg(["mean", "median", "max", "min"]).to_frame("Undergrad population - commencement happened")
# Out:
#         Undergrad population - let stand
# mean                              31,594
# median                            10,610
# max                              413,099
# min                                3,493

# %% [markdown]
# ## share of schools that had counter protesters

# %%
## find share of schools that had negotiations - commencement canceled
(df_canceled.value_counts("counterprotesters", normalize = True)*100).to_frame("Had counterprotesters? - commencement canceled")
# Out:
#                                       Had counterprotesters? - arrests
# counterprotesters
# No                                                                  62
# Yes                                                                 33
# school security protected encampment                                 5

# %%
## find share of schools that had negotiations - commencement happened
(df_commencement.value_counts("counterprotesters", normalize = True)*100).to_frame("Had counterprotesters? - commencement happened")
# Out:
#                                       Had counterprotesters? - let stand
# counterprotesters
# No                                                                    62
# Yes                                                                   33
# school security protected encampment                                   5

# %% [markdown]
# ## share of schools that are in states with anti-BDS laws

# %%
## find share of schools that had negotiations - commencement canceled
(df_canceled.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law? - commencement canceled")
# Out:
#                 Anti BDS law? - arrests
# anti_bds_state
# Yes                                  47
# yes                                  27
# No                                   20
# no                                    7

# %%
## find share of schools that had negotiations - commencement happened
(df_commencement.value_counts("anti_bds_state", normalize = True)*100).to_frame("Anti BDS law? - commencement happened")
# Out:
#                 Anti BDS law? - let stand
# anti_bds_state
# Yes                                    47
# yes                                    27
# No                                     20
# no                                      7

# %% [markdown]
# ## share of schools with arrested students

# %%
## find share of schools with arrested students - commencement canceled
(df_canceled.value_counts("university_response", normalize = True)*100).to_frame("School response - commencement canceled")
# Out:
#                      School response - success
# university_response
# let stand                                   75
# agreed                                      25

# %%
## find share of schools with arrested students - commencement happened
(df_commencement.value_counts("university_response", normalize = True)*100).to_frame("School response - commencement happened")
# Out:
#                      School response - no
# university_response
# arrests                                78
# let stand                              13
# discipline threat                       9
